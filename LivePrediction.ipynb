# %%
import pandas as pd
import numpy as np
from scrapper import Scrapper

# %%
url = 'https://in.tradingview.com/markets/stocks-india/news/'

scrapper = Scrapper(url)
titles = scrapper.get_all_article_titles()
titles_array = np.array(titles)
# titles_array.shape
titles
# Out:
# ["India's Power Grid's profit slips on subdued transmission demand",
#  "India's Petronet eyes lower prices under renewed long-term deal with Qatar",
#  'Reliance Retail to launch $200-laptop to replicate phone success',
#  "India's Adani Group plans $1.82-bln fundraise through bond market - Bloomberg News",
#  "India's Heritage Foods posts two-fold surge in Q1 profit on higher milk demand, prices",
#  "After Sequoia split, India's Peak XV to hold CEOs meet for first time",
#  'Sri Lankan shares end higher as industrials, financials rise',
#  "State Bank of India's infra bond response likely to lure other banks into tapping mkt - bankers",
#  'Indian Equities Close Higher as US, Eurozone Inflation Cools',
#  'ICICI Securities to issue 3-month CP - bankers',
#  'Fund managers sceptical of infra stocks opportunity because of past experience: Nilesh Shah',
#  'XOM: Exxon Mobil Profits Drop 55% Dragged by Falling Oil Prices, Shares Resist Selloff',
#  'Grasim Industries accepts bids for 3-year bonds - bankers',
#  'HDFC Securities to issue 3-month CP - bankers',
#  "Sensex, Nifty gain 2.7% in July; analysts cautious about FIIs' future purchases",
#  'Taking Stock: Market bounces back; Nifty above 19,750; Sensex up 367 points',
#  'Metals, power, IT stocks lead rise in Indian shares',
#  "India's UPL reports lower-than-expected profit on weak demand",
#  "Foxconn's EV consortium to use BlackBerry's software",
#  'Rupee ends almost flat ahead of key U.S. data sets; falls in July',
#  'Hold Nestle India; target of Rs 24,650: Sharekhan',
#  'Hold Shree Cement; target of Rs 26,400: Sharekhan',
#  'Buy Indian Hotels Company; target of Rs 450: Sharekhan',
#  'Buy Birlasoft; target of Rs 470: Sharekhan',
#  'Buy Alicon Castalloy; target of Rs 999: Sharekhan',
#  'Buy Punjab National Bank; target of Rs 72: Sharekhan',
#  'Buy Mahindra Lifespace Developers; target of Rs 580: Sharekhan',
#  'Buy Schaeffler India; target of Rs 3406: Sharekhan',
#  'Buy Tata Consumer Products; target of Rs 1010: Sharekhan',
#  'Buy Dhampur Bio Organics; target of Rs 215: Sharekhan',
#  'Buy Arvind; target of Rs 164: Sharekhan',
#  'Buy JK Lakshmi Cement; target of Rs 770: Sharekhan',
#  'Buy Coromandel International; target of Rs 1155: Sharekhan',
#  'Buy Marico; target of Rs 645: Sharekhan',
#  'Buy Bharat Electronics; target of Rs 151: Sharekhan',
#  'Walmart focuses India’s retail valuation debate',
#  'HEG sees flag-&-pole pattern breakout, may fetch substantial returns',
#  'Hold Birlasoft; target of Rs 452: Religare Retail Research',
#  'Accumulate Tech Mahindra; target of Rs 1207: KR Choksey',
#  'Accumulate Bajaj Auto; target of Rs 5321: KR Choksey',
#  'Buy Dr Reddys Labs; target of Rs 6560: KR Choksey',
#  'Buy Kotak Mahindra Bank; target of Rs 2330: KR Choksey',
#  'Buy Shree Cement; target of Rs 29,250: KR Choksey',
#  "Markets are a 'Triveni Sangam' of fundamentals, flows and sentiment: Nilesh Shah",
#  "India's Siemens hits record high after shareholders reject sale of division",
#  "India's Kapston Services rises most in two months on Q1 profit jump",
#  'India’s growth story takes a leaf out of Akbar-Birbal Kahani, says Nilesh Shah',
#  "India's Go Fashion gains on June quarter earnings rise",
#  'DCB Bank tanks 5% on muted Q1 results, weaker asset quality',
#  "India's Solar Energy Corp proposes joint venture with Reliance - sources",
#  "India's Bharti Airtel prepays $976 mln to partly clear 2015 spectrum dues",
#  'Ujjivan Small Finance Bank surges 10% to 52-week high on record 60% rise in net',
#  'Most Asian shares rise on slowing US inflation, FX mixed',
#  "India's Laxmi Organic Industries climbs on capex plan",
#  'Buy CMS Info Systems; target of Rs 465: JM Financial',
#  'RPG Life Sciences hits 52-week high as Q1 profit surges 22%',
#  'Buy CMS Info Systems; target of Rs 449: IIFL Securities',
#  'Buy Sona BLW Precision Forgings; target of Rs 640: LKP Research',
#  "Mahindra Finance's higher provisions, shrinking margins keep analysts concerned"]

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

processed_titles = []
for title in titles:
    doc = nlp(title)
    processed_title = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        processed_title.append(token.lemma_.lower())
    processed_titles.append(processed_title)
processed_titles = np.array(processed_titles)
print(type(processed_titles))
processed_titles[:3]
# Out:
# <class 'numpy.ndarray'>
# C:\Users\malav\AppData\Local\Temp\ipykernel_25720\1159102760.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   processed_titles = np.array(processed_titles)
# array([list(['india', 'power', 'grid', 'profit', 'slip', 'subdued', 'transmission', 'demand']),
#        list(['india', 'petronet', 'eye', 'lower', 'price', 'renew', 'long', 'term', 'deal', 'qatar']),
#        list(['reliance', 'retail', 'launch', '$', '200', 'laptop', 'replicate', 'phone', 'success'])],
#       dtype=object)

# %%
df = pd.DataFrame(processed_titles)
df['Original'] = titles
df.head()
# Out:
#                                                    0  \
# 0  [india, power, grid, profit, slip, subdued, tr...
# 1  [india, petronet, eye, lower, price, renew, lo...
# 2  [reliance, retail, launch, $, 200, laptop, rep...
# 3  [india, adani, group, plan, $, 1.82, bln, fund...
# 4  [india, heritage, foods, post, fold, surge, q1...
#
#                                             Original
# 0  India's Power Grid's profit slips on subdued t...
# 1  India's Petronet eyes lower prices under renew...
# 2  Reliance Retail to launch $200-laptop to repli...
# 3  India's Adani Group plans $1.82-bln fundraise ...
# 4  India's Heritage Foods posts two-fold surge in...

# %%
df.rename(columns={0: 'Text'}, inplace=True)
df.head()
# Out:
#                                                 Text  \
# 0  [india, power, grid, profit, slip, subdued, tr...
# 1  [india, petronet, eye, lower, price, renew, lo...
# 2  [reliance, retail, launch, $, 200, laptop, rep...
# 3  [india, adani, group, plan, $, 1.82, bln, fund...
# 4  [india, heritage, foods, post, fold, surge, q1...
#
#                                             Original
# 0  India's Power Grid's profit slips on subdued t...
# 1  India's Petronet eyes lower prices under renew...
# 2  Reliance Retail to launch $200-laptop to repli...
# 3  India's Adani Group plans $1.82-bln fundraise ...
# 4  India's Heritage Foods posts two-fold surge in...

# %%
def list_to_string(lst):
    return ' '.join(map(str, lst))

# %%
df['Text'] = df['Text'].apply(list_to_string)
df
# Out:
#                                                  Text  \
# 0   india power grid profit slip subdued transmiss...
# 1   india petronet eye lower price renew long term...
# 2   reliance retail launch $ 200 laptop replicate ...
# 3   india adani group plan $ 1.82 bln fundraise bo...
# 4   india heritage foods post fold surge q1 profit...
# 5      sequoia split india peak xv hold ceo meet time
# 6   sri lankan share end higher industrial financi...
# 7   state bank india infra bond response likely lu...
# 8   indian equities close high eurozone inflation ...
# 9            icici securities issue 3 month cp banker
# 10  fund manager sceptical infra stock opportunity...
# 11  xom exxon mobil profits drop 55 drag fall oil ...
# 12    grasim industries accept bid 3 year bond banker
# 13            hdfc securities issue 3 month cp banker
# 14  sensex nifty gain 2.7 july analyst cautious fi...
# 15  take stock market bounce nifty 19,750 sensex 3...
# 16           metal power stock lead rise indian share
# 17     india upl report low expect profit weak demand
# 18      foxconn ev consortium use blackberry software
# 19   rupee end flat ahead key u.s. data set fall july
# 20        hold nestle india target r 24,650 sharekhan
# 21        hold shree cement target r 26,400 sharekhan
# 22   buy indian hotels company target r 450 sharekhan
# 23               buy birlasoft target r 470 sharekhan
# 24        buy alicon castalloy target r 999 sharekhan
# 25     buy punjab national bank target r 72 sharekhan
# 26  buy mahindra lifespace developers target r 580...
# 27       buy schaeffler india target r 3406 sharekhan
# 28  buy tata consumer products target r 1010 share...
# 29    buy dhampur bio organics target r 215 sharekhan
# 30                  buy arvind target r 164 sharekhan
# 31       buy jk lakshmi cement target r 770 sharekhan
# 32  buy coromandel international target r 1155 sha...
# 33                  buy marico target r 645 sharekhan
# 34      buy bharat electronics target r 151 sharekhan
# 35        walmart focus india retail valuation debate
# 36  heg see flag-&-pole pattern breakout fetch sub...
# 37  hold birlasoft target r 452 religare retail re...
# 38  accumulate tech mahindra target r 1207 kr choksey
# 39     accumulate bajaj auto target r 5321 kr choksey
# 40        buy dr reddys labs target r 6560 kr choksey
# 41   buy kotak mahindra bank target r 2330 kr choksey
# 42        buy shree cement target r 29,250 kr choksey
# 43  market triveni sangam fundamental flow sentime...
# 44  india siemens hit record high shareholder reje...
# 45   india kapston services rise month q1 profit jump
# 46  india growth story take leaf akbar birbal kaha...
# 47       india fashion gain june quarter earning rise
# 48  dcb bank tank 5 muted q1 result weak asset qua...
# 49  india solar energy corp propose joint venture ...
# 50  india bharti airtel prepay $ 976 mln partly cl...
# 51  ujjivan small finance bank surge 10 52 week hi...
# 52             asian share rise slow inflation fx mix
# 53    india laxmi organic industries climb capex plan
# 54     buy cms info systems target r 465 jm financial
# 55  rpg life sciences hit 52 week high q1 profit s...
# 56    buy cms info systems target r 449 iifl security
# 57  buy sona blw precision forgings target r 640 l...
# 58  mahindra finance high provision shrink margin ...
#
#                                              Original
# 0   India's Power Grid's profit slips on subdued t...
# 1   India's Petronet eyes lower prices under renew...
# 2   Reliance Retail to launch $200-laptop to repli...
# 3   India's Adani Group plans $1.82-bln fundraise ...
# 4   India's Heritage Foods posts two-fold surge in...
# 5   After Sequoia split, India's Peak XV to hold C...
# 6   Sri Lankan shares end higher as industrials, f...
# 7   State Bank of India's infra bond response like...
# 8   Indian Equities Close Higher as US, Eurozone I...
# 9      ICICI Securities to issue 3-month CP - bankers
# 10  Fund managers sceptical of infra stocks opport...
# 11  XOM: Exxon Mobil Profits Drop 55% Dragged by F...
# 12  Grasim Industries accepts bids for 3-year bond...
# 13      HDFC Securities to issue 3-month CP - bankers
# 14  Sensex, Nifty gain 2.7% in July; analysts caut...
# 15  Taking Stock: Market bounces back; Nifty above...
# 16  Metals, power, IT stocks lead rise in Indian s...
# 17  India's UPL reports lower-than-expected profit...
# 18  Foxconn's EV consortium to use BlackBerry's so...
# 19  Rupee ends almost flat ahead of key U.S. data ...
# 20  Hold Nestle India; target of Rs 24,650: Sharekhan
# 21  Hold Shree Cement; target of Rs 26,400: Sharekhan
# 22  Buy Indian Hotels Company; target of Rs 450: S...
# 23         Buy Birlasoft; target of Rs 470: Sharekhan
# 24  Buy Alicon Castalloy; target of Rs 999: Sharekhan
# 25  Buy Punjab National Bank; target of Rs 72: Sha...
# 26  Buy Mahindra Lifespace Developers; target of R...
# 27  Buy Schaeffler India; target of Rs 3406: Share...
# 28  Buy Tata Consumer Products; target of Rs 1010:...
# 29  Buy Dhampur Bio Organics; target of Rs 215: Sh...
# 30            Buy Arvind; target of Rs 164: Sharekhan
# 31  Buy JK Lakshmi Cement; target of Rs 770: Share...
# 32  Buy Coromandel International; target of Rs 115...
# 33            Buy Marico; target of Rs 645: Sharekhan
# 34  Buy Bharat Electronics; target of Rs 151: Shar...
# 35    Walmart focuses India’s retail valuation debate
# 36  HEG sees flag-&-pole pattern breakout, may fet...
# 37  Hold Birlasoft; target of Rs 452: Religare Ret...
# 38  Accumulate Tech Mahindra; target of Rs 1207: K...
# 39  Accumulate Bajaj Auto; target of Rs 5321: KR C...
# 40  Buy Dr Reddys Labs; target of Rs 6560: KR Choksey
# 41  Buy Kotak Mahindra Bank; target of Rs 2330: KR...
# 42  Buy Shree Cement; target of Rs 29,250: KR Choksey
# 43  Markets are a 'Triveni Sangam' of fundamentals...
# 44  India's Siemens hits record high after shareho...
# 45  India's Kapston Services rises most in two mon...
# 46  India’s growth story takes a leaf out of Akbar...
# 47  India's Go Fashion gains on June quarter earni...
# 48  DCB Bank tanks 5% on muted Q1 results, weaker ...
# 49  India's Solar Energy Corp proposes joint ventu...
# 50  India's Bharti Airtel prepays $976 mln to part...
# 51  Ujjivan Small Finance Bank surges 10% to 52-we...
# 52  Most Asian shares rise on slowing US inflation...
# 53  India's Laxmi Organic Industries climbs on cap...
# 54  Buy CMS Info Systems; target of Rs 465: JM Fin...
# 55  RPG Life Sciences hits 52-week high as Q1 prof...
# 56  Buy CMS Info Systems; target of Rs 449: IIFL S...
# 57  Buy Sona BLW Precision Forgings; target of Rs ...
# 58  Mahindra Finance's higher provisions, shrinkin...

# %%
import joblib

vectorizer = joblib.load('tfidf_vectorizer.joblib')
df_text_transformed = vectorizer.transform(df['Text'])
df_text_transformed
# Out:
# <59x9946 sparse matrix of type '<class 'numpy.float64'>'
# 	with 339 stored elements in Compressed Sparse Row format>

# %%
import joblib

loaded_model = joblib.load('model.joblib')


predictions = loaded_model.predict(df_text_transformed)
df['predictions'] = predictions
df['predictions'] = df['predictions'].apply(lambda x: 'Buy' if x == 1 else 'Sell')
df.head(10)
# Out:
#                                                 Text  \
# 0  india power grid profit slip subdued transmiss...
# 1  india petronet eye lower price renew long term...
# 2  reliance retail launch $ 200 laptop replicate ...
# 3  india adani group plan $ 1.82 bln fundraise bo...
# 4  india heritage foods post fold surge q1 profit...
# 5     sequoia split india peak xv hold ceo meet time
# 6  sri lankan share end higher industrial financi...
# 7  state bank india infra bond response likely lu...
# 8  indian equities close high eurozone inflation ...
# 9           icici securities issue 3 month cp banker
#
#                                             Original predictions
# 0  India's Power Grid's profit slips on subdued t...         Buy
# 1  India's Petronet eyes lower prices under renew...         Buy
# 2  Reliance Retail to launch $200-laptop to repli...         Buy
# 3  India's Adani Group plans $1.82-bln fundraise ...         Buy
# 4  India's Heritage Foods posts two-fold surge in...        Sell
# 5  After Sequoia split, India's Peak XV to hold C...         Buy
# 6  Sri Lankan shares end higher as industrials, f...         Buy
# 7  State Bank of India's infra bond response like...         Buy
# 8  Indian Equities Close Higher as US, Eurozone I...         Buy
# 9     ICICI Securities to issue 3-month CP - bankers         Buy
